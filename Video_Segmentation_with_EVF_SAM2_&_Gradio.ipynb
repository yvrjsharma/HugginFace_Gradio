# %% [markdown]
# <a href="https://colab.research.google.com/github/yvrjsharma/HugginFace_Gradio/blob/main/Video_Segmentation_with_EVF_SAM2_%26_Gradio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Step1: Clone the Huggingface Space for EVF-SAM2 : https://huggingface.co/spaces/wondervictor/evf-sam2

# %%
# !git clone https://huggingface.co/spaces/wondervictor/evf-sam2
# Out:
# Cloning into 'evf-sam2'...
# remote: Enumerating objects: 273, done.
# remote: Counting objects: 100% (145/145), done.
# remote: Compressing objects: 100% (140/140), done.
# remote: Total 273 (delta 70), reused 4 (delta 4), pack-reused 128 (from 1)
# Receiving objects: 100% (273/273), 3.75 MiB | 12.02 MiB/s, done.
# Resolving deltas: 100% (101/101), done.

# %% [markdown]
# ### Step2 : Change directory to the cloned repo evf-sam2

# %%
# %cd evf-sam2
# Out:
# /content/evf-sam2

# %% [markdown]
# ### Install required dependencies from `requirements.txt`

# %%
# !pip install -r requirements.txt -q

# %%
# !pip install spaces -q

# %% [markdown]
# ### Launch the Gradio app
# - Make sure to set `share=True` in `demo.lauunch()` in the app.py file before launching the demo.
# - This will create a public link for the demo.

# %%
# !python app.py
